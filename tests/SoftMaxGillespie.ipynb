# %%
import numpy as np
from stopro import gillespie_replicator

# %%
gillespie_replicator(10000,dt=1,steps=2)
# Out:
# {'X': array([[[5.00000000e-01, 1.00000000e+00, 1.00000000e+00],
#          [5.00000000e-01, 4.60821308e-66, 4.00303095e-44]]]),
#  't': array([    0.,  5000., 10000.]),
#  'dt': 5000.0,
#  'steps': 2,
#  'savedsteps': 2,
#  'N': 2,
#  'gap': 1,
#  'mu': array([1., 1.]),
#  'sigma': array([1., 1.]),
#  'initial_condition': array([0.5, 0.5]),
#  'noise_covariance': None}

# %%
gillespie_replicator_softmax(10000,0.01,steps=2)
# Out:
# {'X': array([[[5.00000000e-01, 1.26730773e-11, 9.80926948e-01],
#          [5.00000000e-01, 1.00000000e+00, 1.90730516e-02]]]),
#  't': array([    0.,  5000., 10000.]),
#  'dt': 5000.0,
#  'steps': 2,
#  'savedsteps': 2,
#  'N': 2,
#  'gap': 1,
#  'mu': array([1., 1.]),
#  'sigma': array([1., 1.]),
#  'initial_condition': array([0.5, 0.5]),
#  'noise_covariance': None}
