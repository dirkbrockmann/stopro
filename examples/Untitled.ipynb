# %%
import stopro

# %%
stopro.wiener(10,0.01)
# Out:
# {'X': array([[[0.        ],
#          [0.20910081],
#          [0.33120313],
#          ...,
#          [3.96719038],
#          [3.8562069 ],
#          [3.83509151]]], shape=(1, 1001, 1)),
#  't': array([ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ], shape=(1001,)),
#  'dt': 0.01,
#  'steps': 1000,
#  'savedsteps': 1000,
#  'N': 1,
#  'gap': 1,
#  'covariance': array([[1.]]),
#  'order': 'STD'}

# %%
stopro
